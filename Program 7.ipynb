# %% [markdown]
# # Find values in a column that are greater than 100.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
print("Here are the value which is greater than 100\n")
print(df[df['Marks'] > 100])
# Out:
# Here are the value which is greater than 100
#
#       Name  Age  Marks Gender      City
# 4    David   20  110.0   Male  New York
# 6  Michael   21  150.0   Male     Tokyo
