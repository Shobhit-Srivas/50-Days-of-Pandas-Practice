# %% [markdown]
# # Delete the City column from the DataFrame.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
df.drop('City', axis = 1, inplace = True)
df
# Out:
#        Name  Age  Marks  Gender
# 0      John   20   85.0    Male
# 1     Alice   21   92.0  Female
# 2       Bob   19   45.0    Male
# 3      Emma   22    NaN  Female
# 4     David   20  110.0    Male
# 5    Sophia   23   78.0  Female
# 6   Michael   21  150.0    Male
# 7    Olivia   20   65.0  Female
# 8      John   20   85.0    Male
# 9      Liam   22    NaN    Male
# 10     Noah   24   55.0    Male
# 11      Ava   21   99.0  Female
