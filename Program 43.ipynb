# %% [markdown]
# # Select rows by index using iloc.

# %%
import pandas as pd
df = pd.read_csv('sales.csv')
print(df.iloc[0:3])
# Out:
#   Region Product  Sales
# 0  North  Laptop  50000
# 1  South  Mobile  25000
# 2   East  Laptop  45000
