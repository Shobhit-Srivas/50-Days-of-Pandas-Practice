# %% [markdown]
# # Select rows by label using loc.

# %%
import pandas as pd
df = pd.read_csv('sales.csv')
df.loc[2]
# Out:
# Region       East
# Product    Laptop
# Sales       45000
# Name: 2, dtype: object
