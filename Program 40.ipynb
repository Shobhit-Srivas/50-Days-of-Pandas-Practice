# %% [markdown]
# # Display all column names.

# %%
import pandas as pd
df = pd.read_csv('employee.csv')
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Salary', 'Experience'], dtype='object')
