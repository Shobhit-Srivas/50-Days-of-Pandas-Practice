# %% [markdown]
# # Count employees in each department.

# %%
import pandas as pd
df = pd.read_csv('employee.csv')
df
# Out:
#    EmployeeID     Name Department  Salary  Experience
# 0         101     John         IT   60000           3
# 1         102    Alice         HR   55000           2
# 2         103      Bob         IT   75000           5
# 3         104     Emma    Finance   70000           4
# 4         105    David         HR   50000           1
# 5         106   Sophia    Finance   85000           7
# 6         107  Michael         IT   90000           8
# 7         108   Olivia         HR   62000           3
# 8         109     Liam    Finance   78000           5
# 9         110     Noah         IT   65000           4

# %%
employee_count = df.groupby("Department")["Name"].count()
print(employee_count)
# Out:
# Department
# Finance    3
# HR         3
# IT         4
# Name: Name, dtype: int64
