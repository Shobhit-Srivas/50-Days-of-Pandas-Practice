# %% [markdown]
# # Generate descriptive statistics using describe().

# %%
import pandas as pd
df = pd.read_csv('employee.csv')
df.describe()
# Out:
#        EmployeeID        Salary  Experience
# count    10.00000     10.000000   10.000000
# mean    105.50000  69000.000000    4.200000
# std       3.02765  12987.173159    2.149935
# min     101.00000  50000.000000    1.000000
# 25%     103.25000  60500.000000    3.000000
# 50%     105.50000  67500.000000    4.000000
# 75%     107.75000  77250.000000    5.000000
# max     110.00000  90000.000000    8.000000
