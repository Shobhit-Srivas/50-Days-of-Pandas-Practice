# %% [markdown]
# # Divide all values in a numeric column by 100.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
df['Marks'] = df['Marks'] / 100
df
# Out:
#        Name  Age  Marks  Gender      City
# 0      John   20   0.85    Male  New York
# 1     Alice   21   0.92  Female    London
# 2       Bob   19   0.45    Male     Paris
# 3      Emma   22    NaN  Female    London
# 4     David   20   1.10    Male  New York
# 5    Sophia   23   0.78  Female     Paris
# 6   Michael   21   1.50    Male     Tokyo
# 7    Olivia   20   0.65  Female    London
# 8      John   20   0.85    Male  New York
# 9      Liam   22    NaN    Male    Berlin
# 10     Noah   24   0.55    Male     Tokyo
# 11      Ava   21   0.99  Female     Paris
