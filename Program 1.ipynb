# %% [markdown]
# # Count how many missing values are in a DataFrame.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
print(f"Total Missing Values are in a DataFrame:\n{df.isnull().sum()}")
# Out:
# Total Missing Values are in a DataFrame:
# Name      0
# Age       0
# Marks     2
# Gender    0
# City      0
# dtype: int64
