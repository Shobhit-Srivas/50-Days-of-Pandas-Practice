# %% [markdown]
# # Print the maximum and minimum value of a column.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
print(f"Maximum Value of Marks is:\n {df['Marks'].max()}")
print(f"Minimum Value of Marks is:\n {df['Marks'].min()}")
# Out:
# Maximum Value of Marks is:
#  150.0
# Minimum Value of Marks is:
#  45.0
