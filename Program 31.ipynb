# %% [markdown]
# # Create a DataFrame of Sales with columns: Region, Product, Sales.

# %%
import pandas as pd
df = pd.read_csv('sales.csv')
df
# Out:
#    Region Product  Sales
# 0   North  Laptop  50000
# 1   South  Mobile  25000
# 2    East  Laptop  45000
# 3    West  Tablet  15000
# 4   North  Mobile  30000
# 5   South  Laptop  55000
# 6    East  Tablet  20000
# 7    West  Mobile  35000
# 8   North  Tablet  18000
# 9   South  Mobile  28000
# 10   East  Laptop  48000
# 11   West  Laptop  52000
