# %% [markdown]
# # Access only the Name column from the DataFrame.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
print('Name:')
df['Name']
# Out:
# Name:
# 0        John
# 1       Alice
# 2         Bob
# 3        Emma
# 4       David
# 5      Sophia
# 6     Michael
# 7      Olivia
# 8        John
# 9        Liam
# 10       Noah
# 11        Ava
# Name: Name, dtype: object
