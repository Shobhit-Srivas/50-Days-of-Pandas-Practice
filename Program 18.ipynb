# %% [markdown]
# # Show the mean and standard deviation of a numeric column.

# %%
import pandas as pd
df = pd.read_csv('students.csv')
print(f"Mean value of Marks is: {df['Marks'].mean()}")
print(f"Standard deviation value of Marks is: {df['Marks'].std()}")
# Out:
# Mean value of Marks is: 86.4
# Standard deviation value of Marks is: 29.859671799937786
